# %%
import networkcommons as nc

# %% [markdown]
# # TODOs:
#
# Similar to data and knowledge, one of the most important functionalities is to create a table with the description and input of each method included. This will help to understand the methods and their differences. We should also provide some type of high-level category. E.g. (Baselines, ILP-based (CARNIVAL/CORNETO), Recursive enrichment (Moon), RWR-based (PageRank), etc.). We can take some inspiration from the review. But this will be the harder one to create.
#
# Re input, this will be tricky. For now we have no method that needs observational data (sample-level information), but differential analysis results. But this may change in the future. I am thinking if for this particular instance, a more structured version of the code is needed (maybe some classes like differential_estimates / observations ... etc), which can be directly used to run the method or to query the prior knowledge. TBD in person

# %%
nc.list_methods()
